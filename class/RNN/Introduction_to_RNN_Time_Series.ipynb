# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/RNN/Introduction_to_RNN_Time_Series.ipynb">
#         <img src="https://i.ibb.co/2P3SLwK/colab.png"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/RNN/Introduction_to_RNN_Time_Series.ipynb">
#         <img src="https://i.ibb.co/xfJbPmL/github.png"  height="70px" style="padding-bottom:5px;"  />View Source on GitHub</a></td>
# </table>

# %% [markdown]
# #### Import keras

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Simple Architectures

# %% [markdown]
# There are three built-in RNN layers in Keras:
#
# 1. [`keras.layers.SimpleRNN`](https://keras.io/api/layers/recurrent_layers/simple_rnn/), a fully-connected RNN where the output from previous
# timestep is to be fed to next timestep.
#
# ```python
# tf.keras.layers.SimpleRNN(
#     units,
#     dropout=0.0,
#     recurrent_dropout=0.0,
#     return_sequences=False,
#     return_state=False,
#     go_backwards=False,
#     stateful=False,
# )
# ````
#
# 2. [`keras.layers.GRU`](https://keras.io/api/layers/recurrent_layers/gru/), first proposed in
# [Cho et al., 2014](https://arxiv.org/abs/1406.1078).
# ```python
# tf.keras.layers.GRU(
#     units,
#     dropout=0.0,
#     recurrent_dropout=0.0,
#     return_sequences=False,
#     return_state=False,
#     go_backwards=False,
#     stateful=False,
# )
# ```
#
# 3. [`keras.layers.LSTM`](https://keras.io/api/layers/recurrent_layers/lstm/), first proposed in
# [Hochreiter & Schmidhuber, 1997](https://www.bioinf.jku.at/publications/older/2604.pdf).
# ```python
# tf.keras.layers.LSTM(
#     units,
#     dropout=0.0,
#     recurrent_dropout=0.0,
#     return_sequences=False,
#     return_state=False,
#     go_backwards=False,
#     stateful=False,
# )
# ````
# For more information, see the
# [RNN API documentation](https://keras.io/api/layers/recurrent_layers/).
#
#
#
#
#
# In time series forecasting we are going to use the **many-to-one** architecture with default parameter `return_sequences=False`.
#
# The shape of the output  for this architecture  is `(batch_size, units)`.
# where `units` corresponds to the `units` argument passed to the layer's constructor.
#
# Lets see one some examples for understanding the input/output dimensions:

# %%
# dims of input: [batch, timesteps, features]
inputs = tf.random.normal([32, 10, 4])
print('input dim (batch, timesteps, feature): ', inputs.shape)
# return_sequences=False, return_state=False
lstm = tf.keras.layers.LSTM(units= 2)
output = lstm(inputs)
print('return_state=False output shape: ',output.shape)
# Out:
# input dim (batch, timesteps, feature):  (32, 10, 4)
# return_state=False output shape:  (32, 2)

# %% [markdown]
# ### Deep RNN
# We can stack multiple layers of RNNs on top of each other. Each hidden state is continuously passed to both the next time step of the current layer and the current time step of the next layer.
#
# For stack another RNN layer to an existing one, we need to use the states with `return_sequences=True`

# %%
## We can modify the input vector before the rnn cell with TimeDistributed
timesteps = 10
features = 8 # dimension of the innput of every cell

#Shape [batch, timesteps, features] 
inputs = tf.keras.Input(shape=(timesteps, features), name='input')
lstm_1 = layers.LSTM(64, return_sequences=True, name='lstm_1')(inputs)
lstm_2 = layers.LSTM(64, return_sequences=True, name='lstm_2')(lstm_1)
# last lstm layer depends in [one to many or  many to many]
lstm_3 = layers.LSTM(64, return_sequences=False, name='lstm_3')(lstm_2)
model = keras.Model(inputs=inputs, outputs=lstm_3, name='rnn_example')
#print(model.summary())
inputs = tf.random.normal([32, timesteps, features])
print(model(inputs).shape)
# Out:
# (32, 64)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %% [markdown]
# ### Bidirectional RNNs
#
# For sequences other than time series (e.g. text), it is often the case that a RNN model
# can perform better if it not only processes sequence from start to end, but also
# backwards. For example, to predict the next word in a sentence, it is often useful to
# have the context around the word, not only just the words that come before it.
#
# Keras provides an easy API for you to build such bidirectional RNNs: the
# `keras.layers.Bidirectional` wrapper.
#
# [link to documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Bidirectional)

# %%
model = keras.Sequential()

# If you crete a second layer you must set return_sequences=True
model.add(
    layers.Bidirectional(layers.LSTM(64, return_sequences=True), input_shape=(timesteps, features))
)
# Second Bidirectional layer
model.add(layers.Bidirectional(layers.LSTM(32)))
# Output
model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 10, 128)           37376
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense (Dense)                (None, 10)                650
# =================================================================
# Total params: 79,242
# Trainable params: 79,242
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# #### Windowing sequences
#
# <img src="https://i.ibb.co/5nvJQB4/split-window.png" alt="cnn" border="0">
#
# Creates a dataset of sliding windows over a timeseries provided as array with [timeseries_dataset_from_array](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/timeseries_dataset_from_array).

# %% [markdown]
# For creating the windows we use [timeseries_dataset_from_array](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/timeseries_dataset_from_array)
#
# ```python
# tf.keras.preprocessing.timeseries_dataset_from_array(
#     data, targets, sequence_length, sequence_stride=1, sampling_rate=1,
#     batch_size=128, shuffle=False, seed=None, start_index=None, end_index=None
# )
# ```
#
# For preprocessing the input we are going to use `prepare_dataset`

# %%
def prepare_dataset(ts, past, future, batch_size):
    start = past + future - 1
    x = ts[:-past + 1]
    y = ts[start:start + len(x)]
    # padding
    y = np.concatenate([y, np.zeros(len(x) - len(y))])
    dataset = keras.preprocessing.timeseries_dataset_from_array(
        x,
        y,
        sequence_length=past,
        batch_size=batch_size,
    )
    return dataset

# %% [markdown]
# ### Airlines Dataset

# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import math
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
#df = pd.read_csv('../data/airline-passengers.csv', usecols=[1])
url = 'https://c4science.ch/diffusion/2096/browse/master/input/international-airline-passengers.csv'
df = pd.read_csv(url, usecols=[1], nrows=144)
dataset = df.values  # .flatten()
plt.plot(dataset)
plt.show()

# %% [markdown]
# Split in train/test set and scale with  StandardScaler

# %%
split_fraction = 0.75
train_split = int(split_fraction * int(len(dataset)))


from sklearn.preprocessing import StandardScaler
# scale the data
scaler = StandardScaler()
scaler.fit(dataset[:train_split])


dataset_s = scaler.fit_transform(dataset).flatten()
plt.plot(dataset_s)
plt.show()

# %%
# split into train and test sets
train, test = dataset_s[0:train_split], dataset_s[train_split:len(dataset)]
print(len(train), len(test))
# Out:
# 108 36

# %%
# lenght of sequence for predicting
past = 2
# future steps to predict
future = 1

batch_size = 4
dataset_train = prepare_dataset(train, past, future,
                    batch_size)
dataset_val = prepare_dataset(test, past, future,
                    batch_size)

# %%
for windows, targets in dataset_train:
    print('windows shape: {}'.format(windows.shape))
    print('targets shape: {}'.format(targets.shape))
    for i in range(len(targets)):
        print('window,target: {},{}'.format(windows[i,:].numpy(), targets[i].numpy()))   
    break
# Out:
# windows shape: (4, 2)
# targets shape: (4,)
# window,target: [-1.40777884 -1.35759023],-1.2404834803335385
# window,target: [-1.35759023 -1.24048348],-1.2655777844077172
# window,target: [-1.24048348 -1.26557778],-1.3324959286055273
# window,target: [-1.26557778 -1.33249593],-1.2153891762593596

# %%
inputs_shape = (past, 1)
inputs = keras.layers.Input(shape=(past,1))
lstm_out_1 = keras.layers.LSTM(32, return_sequences=False)(inputs)
outputs = keras.layers.Dense(1)(lstm_out_1)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), loss="mse")
model.summary()

history = model.fit(
    dataset_train,
    epochs=100,
    validation_data=dataset_val
)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2, 1)]            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 27/27 [==============================] - 8s 114ms/step - loss: 0.6541 - val_loss: 1.3919
# Epoch 2/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.4017 - val_loss: 1.2128
# Epoch 3/100
# 27/27 [==============================] - 0s 11ms/step - loss: 0.2268 - val_loss: 1.0449
# Epoch 4/100
# 27/27 [==============================] - 0s 15ms/step - loss: 0.1114 - val_loss: 0.9004
# Epoch 5/100
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0595 - val_loss: 0.7854
# Epoch 6/100
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0443 - val_loss: 0.6952
# Epoch 7/100
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0403 - val_loss: 0.6229
# Epoch 8/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0386 - val_loss: 0.5658
# Epoch 9/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0376 - val_loss: 0.5226
# Epoch 10/100
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0370 - val_loss: 0.4912
# Epoch 11/100
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0367 - val_loss: 0.4692
# Epoch 12/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0366 - val_loss: 0.4543
# Epoch 13/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0365 - val_loss: 0.4443
# Epoch 14/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.0364 - val_loss: 0.4377
# Epoch 15/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0363 - val_loss: 0.4331
# Epoch 16/100
# 27/27 [==============================] - 1s 25ms/step - loss: 0.0362 - val_loss: 0.4299
# Epoch 17/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0361 - val_loss: 0.4273
# Epoch 18/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0360 - val_loss: 0.4251
# Epoch 19/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0358 - val_loss: 0.4229
# Epoch 20/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0357 - val_loss: 0.4208
# Epoch 21/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0356 - val_loss: 0.4186
# Epoch 22/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0354 - val_loss: 0.4163
# Epoch 23/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0352 - val_loss: 0.4139
# Epoch 24/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0351 - val_loss: 0.4113
# Epoch 25/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0349 - val_loss: 0.4086
# Epoch 26/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0347 - val_loss: 0.4058
# Epoch 27/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0345 - val_loss: 0.4028
# Epoch 28/100
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0343 - val_loss: 0.3997
# Epoch 29/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0341 - val_loss: 0.3964
# Epoch 30/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0339 - val_loss: 0.3931
# Epoch 31/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0337 - val_loss: 0.3896
# Epoch 32/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0334 - val_loss: 0.3860
# Epoch 33/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0332 - val_loss: 0.3822
# Epoch 34/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0330 - val_loss: 0.3784
# Epoch 35/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0327 - val_loss: 0.3744
# Epoch 36/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0324 - val_loss: 0.3702
# Epoch 37/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0321 - val_loss: 0.3659
# Epoch 38/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0319 - val_loss: 0.3615
# Epoch 39/100
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0316 - val_loss: 0.3569
# Epoch 40/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0312 - val_loss: 0.3522
# Epoch 41/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0309 - val_loss: 0.3473
# Epoch 42/100
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0306 - val_loss: 0.3422
# Epoch 43/100
# 27/27 [==============================] - 1s 38ms/step - loss: 0.0303 - val_loss: 0.3369
# Epoch 44/100
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0299 - val_loss: 0.3314
# Epoch 45/100
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0295 - val_loss: 0.3258
# Epoch 46/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0292 - val_loss: 0.3198
# Epoch 47/100
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0288 - val_loss: 0.3137
# Epoch 48/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0285 - val_loss: 0.3073
# Epoch 49/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0281 - val_loss: 0.3007
# Epoch 50/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0277 - val_loss: 0.2938
# Epoch 51/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0274 - val_loss: 0.2867
# Epoch 52/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0270 - val_loss: 0.2794
# Epoch 53/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0267 - val_loss: 0.2721
# Epoch 54/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0263 - val_loss: 0.2649
# Epoch 55/100
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0260 - val_loss: 0.2580
# Epoch 56/100
# 27/27 [==============================] - 0s 11ms/step - loss: 0.0257 - val_loss: 0.2515
# Epoch 57/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0255 - val_loss: 0.2457
# Epoch 58/100
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0252 - val_loss: 0.2407
# Epoch 59/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0250 - val_loss: 0.2366
# Epoch 60/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0248 - val_loss: 0.2334
# Epoch 61/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0246 - val_loss: 0.2310
# Epoch 62/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0245 - val_loss: 0.2293
# Epoch 63/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0244 - val_loss: 0.2282
# Epoch 64/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0243 - val_loss: 0.2275
# Epoch 65/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0242 - val_loss: 0.2272
# Epoch 66/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0241 - val_loss: 0.2271
# Epoch 67/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0241 - val_loss: 0.2271
# Epoch 68/100
# 27/27 [==============================] - 1s 23ms/step - loss: 0.0240 - val_loss: 0.2272
# Epoch 69/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0240 - val_loss: 0.2273
# Epoch 70/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0239 - val_loss: 0.2275
# Epoch 71/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0239 - val_loss: 0.2276
# Epoch 72/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0238 - val_loss: 0.2277
# Epoch 73/100
# 27/27 [==============================] - 1s 28ms/step - loss: 0.0238 - val_loss: 0.2279
# Epoch 74/100
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0238 - val_loss: 0.2280
# Epoch 75/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.0238 - val_loss: 0.2281
# Epoch 76/100
# 27/27 [==============================] - 1s 26ms/step - loss: 0.0237 - val_loss: 0.2282
# Epoch 77/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0237 - val_loss: 0.2283
# Epoch 78/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0237 - val_loss: 0.2284
# Epoch 79/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0237 - val_loss: 0.2285
# Epoch 80/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0236 - val_loss: 0.2286
# Epoch 81/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0236 - val_loss: 0.2287
# Epoch 82/100
# 27/27 [==============================] - 1s 29ms/step - loss: 0.0236 - val_loss: 0.2288
# Epoch 83/100
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0236 - val_loss: 0.2289
# Epoch 84/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0236 - val_loss: 0.2290
# Epoch 85/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0235 - val_loss: 0.2292
# Epoch 86/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0235 - val_loss: 0.2293
# Epoch 87/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0235 - val_loss: 0.2295
# Epoch 88/100
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0235 - val_loss: 0.2296
# Epoch 89/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0235 - val_loss: 0.2298
# Epoch 90/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0235 - val_loss: 0.2299
# Epoch 91/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.2301
# Epoch 92/100
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0234 - val_loss: 0.2303
# Epoch 93/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0234 - val_loss: 0.2305
# Epoch 94/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0234 - val_loss: 0.2307
# Epoch 95/100
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0234 - val_loss: 0.2309
# Epoch 96/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0234 - val_loss: 0.2311
# Epoch 97/100
# 27/27 [==============================] - 0s 14ms/step - loss: 0.0234 - val_loss: 0.2313
# Epoch 98/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0234 - val_loss: 0.2315
# Epoch 99/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.2318
# Epoch 100/100
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0234 - val_loss: 0.2320

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xticks([])
    plt.xlabel("Time-Step")
    plt.show()
    return


for x, y in dataset_val.take(5):
    x_in = scaler.inverse_transform(x.numpy())
    y_in = scaler.inverse_transform(y.numpy())
    pred = scaler.inverse_transform(model.predict(x))
    show_plot(
        [x_in[0,:], y_in[0], pred.flatten()[0]],
        future,
        "Single Step Prediction",
    )

# %%
# future steps to predict
future = 1
sequence_length = int(past)  # the that steps we use to predict

x = dataset_s[:-past]
# first target oof first window is len(window) + future
y = dataset_s[past:]

batch_size=200
dataset_ts = tf.keras.preprocessing.timeseries_dataset_from_array(
    x, y, sequence_length=past, batch_size=batch_size)
for x, y in dataset_ts:
    x_in = scaler.inverse_transform(x.numpy())
    y_in = scaler.inverse_transform(y.numpy())
    pred = scaler.inverse_transform(model.predict(x))
    
plt.plot(y_in)
plt.plot(pred)
plt.legend(['Real','Prediction'])
plt.show()

# %% [markdown]
# ## Climate Data Time-Series
#
# We will be using Jena Climate dataset recorded by the
# [Max Planck Institute for Biogeochemistry](https://www.bgc-jena.mpg.de/wetter/).
# The dataset consists of 14 features such as temperature, pressure, humidity etc, recorded once per
# 10 minutes.
#
# **Location**: Weather Station, Max Planck Institute for Biogeochemistry
# in Jena, Germany
#
# **Time-frame Considered**: Jan 10, 2009 - December 31, 2016
#
#
# The table below shows the column names, their value formats, and their description.
#
# Index| Features      |Format             |Description
# -----|---------------|-------------------|-----------------------
# 1    |Date Time      |01.01.2009 00:10:00|Date-time reference
# 2    |p (mbar)       |996.52             |The pascal SI derived unit of pressure used to quantify internal pressure. Meteorological reports typically state atmospheric pressure in millibars.
# 3    |T (degC)       |-8.02              |Temperature in Celsius
# 4    |Tpot (K)       |265.4              |Temperature in Kelvin
# 5    |Tdew (degC)    |-8.9               |Temperature in Celsius relative to humidity. Dew Point is a measure of the absolute amount of water in the air, the DP is the temperature at which the air cannot hold all the moisture in it and water condenses.
# 6    |rh (%)         |93.3               |Relative Humidity is a measure of how saturated the air is with water vapor, the %RH determines the amount of water contained within collection objects.
# 7    |VPmax (mbar)   |3.33               |Saturation vapor pressure
# 8    |VPact (mbar)   |3.11               |Vapor pressure
# 9    |VPdef (mbar)   |0.22               |Vapor pressure deficit
# 10   |sh (g/kg)      |1.94               |Specific humidity
# 11   |H2OC (mmol/mol)|3.12               |Water vapor concentration
# 12   |rho (g/m ** 3) |1307.75            |Airtight
# 13   |wv (m/s)       |1.03               |Wind speed
# 14   |max. wv (m/s)  |1.75               |Maximum wind speed
# 15   |wd (deg)       |152.3              |Wind direction in degrees

# %%
from zipfile import ZipFile
import os


uri = "https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip"
zip_path = keras.utils.get_file(origin=uri, fname="jena_climate_2009_2016.csv.zip")
zip_file = ZipFile(zip_path)
zip_file.extractall()
csv_path = "jena_climate_2009_2016.csv"

df = pd.read_csv(csv_path, parse_dates =['Date Time'])
df.head()
# Out:
#             Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0 2009-01-01 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1 2009-01-01 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2 2009-01-01 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3 2009-01-01 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4 2009-01-01 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.75      1.03           1.75     152.3
# 1       1309.80      0.72           1.50     136.1
# 2       1310.24      0.19           0.63     171.6
# 3       1309.19      0.34           0.50     198.0
# 4       1309.00      0.32           0.63     214.3

# %% [markdown]
# ### Raw Data Visualization
#
# To give us a sense of the data we are working with, each feature has been plotted below.
# This shows the distinct pattern of each feature over the time period from 2009 to 2016.
# It also shows where anomalies are present, which will be addressed during normalization.

# %%
titles = [
    "Pressure",
    "Temperature",
    "Temperature in Kelvin",
    "Temperature (dew point)",
    "Relative Humidity",
    "Saturation vapor pressure",
    "Vapor pressure",
    "Vapor pressure deficit",
    "Specific humidity",
    "Water vapor concentration",
    "Airtight",
    "Wind speed",
    "Maximum wind speed",
    "Wind direction in degrees",
]

feature_keys = [
    "p (mbar)",
    "T (degC)",
    "Tpot (K)",
    "Tdew (degC)",
    "rh (%)",
    "VPmax (mbar)",
    "VPact (mbar)",
    "VPdef (mbar)",
    "sh (g/kg)",
    "H2OC (mmol/mol)",
    "rho (g/m**3)",
    "wv (m/s)",
    "max. wv (m/s)",
    "wd (deg)",
]

colors = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
    "olive",
    "cyan",
]

date_time_key = "Date Time"


def show_raw_visualization(data):
    time_data = data[date_time_key]
    fig, axes = plt.subplots(
        nrows=7, ncols=2, figsize=(15, 20), dpi=80, facecolor="w", edgecolor="k"
    )
    for i in range(len(feature_keys)):
        key = feature_keys[i]
        c = colors[i % (len(colors))]
        t_data = data[key]
        t_data.index = time_data
        t_data.head()
        ax = t_data.plot(
            ax=axes[i // 2, i % 2],
            color=c,
            title="{} - {}".format(titles[i], key),
            rot=25,
        )
        ax.legend([titles[i]])
    plt.tight_layout()


show_raw_visualization(df)

# %% [markdown]
# This heat map shows the correlation between different features.

# %%
def show_heatmap(data):
    plt.matshow(data.corr())
    plt.xticks(range(data.shape[1]), data.columns, fontsize=14, rotation=90)
    plt.gca().xaxis.tick_bottom()
    plt.yticks(range(data.shape[1]), data.columns, fontsize=14)

    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title("Feature Correlation Heatmap", fontsize=14)
    plt.show()


show_heatmap(df)

# %%
selected_features_title = ['Pressure', 'Temperature', 'Saturation vapor pressure',
                 'Vapor pressure deficit', 'Specific' 'humidity', 'Airtight', 'Wind speed']
selected_features = ['p (mbar)',
 'T (degC)',
 'VPmax (mbar)',
 'VPdef (mbar)',
 'sh (g/kg)',
 'rho (g/m**3)',
 'wv (m/s)',
"max. wv (m/s)","wd (deg)" ]

# %% [markdown]
# ### Data Preprocessing
#
# Here we are picking ~300,000 data points for training. Observation is recorded every
# 10 mins, that means 6 times per hour. We will resample one point per hour since no
# drastic change is expected within 60 minutes. We do this via the `sampling_rate`
# argument in `timeseries_dataset_from_array` utility.
#
# We are tracking data from past 720 timestamps (720/6=120 hours). This data will be
# used to predict the temperature after 72 timestamps (76/6=12 hours).
#
# Since every feature has values with
# varying ranges, we do normalization to confine feature values to a range of `[0, 1]` before
# training a neural network.
# We do this by subtracting the mean and dividing by the standard deviation of each feature.
#
# 71.5 % of the data will be used to train the model, i.e. 300,693 rows. `split_fraction` can
# be changed to alter this percentage.
#
# The model is shown data for first 5 days i.e. 720 observations, that are sampled every
# hour. The temperature after 72 (12 hours * 6 observation per hour) observation will be
# used as a label.

# %%
df = df.set_index('Date Time')
## resample by the mean of hour values
df =df.resample('1h').mean().fillna(method='ffill') # 
df.head()
# Out:
#                        p (mbar)  T (degC)    Tpot (K)  Tdew (degC)     rh (%)  \
# Date Time
# 2009-01-01 00:00:00  996.528000 -8.304000  265.118000    -9.120000  93.780000
# 2009-01-01 01:00:00  996.525000 -8.065000  265.361667    -8.861667  93.933333
# 2009-01-01 02:00:00  996.745000 -8.763333  264.645000    -9.610000  93.533333
# 2009-01-01 03:00:00  996.986667 -8.896667  264.491667    -9.786667  93.200000
# 2009-01-01 04:00:00  997.158333 -9.348333  264.026667   -10.345000  92.383333
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# Date Time
# 2009-01-01 00:00:00      3.260000      3.058000      0.202000   1.910000
# 2009-01-01 01:00:00      3.323333      3.121667      0.201667   1.951667
# 2009-01-01 02:00:00      3.145000      2.940000      0.201667   1.836667
# 2009-01-01 03:00:00      3.111667      2.898333      0.210000   1.811667
# 2009-01-01 04:00:00      3.001667      2.775000      0.231667   1.733333
#
#                      H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  \
# Date Time
# 2009-01-01 00:00:00         3.068000   1309.196000  0.520000       1.002000
# 2009-01-01 01:00:00         3.133333   1307.981667  0.316667       0.711667
# 2009-01-01 02:00:00         2.950000   1311.816667  0.248333       0.606667
# 2009-01-01 03:00:00         2.906667   1312.813333  0.176667       0.606667
# 2009-01-01 04:00:00         2.780000   1315.355000  0.290000       0.670000
#
#                        wd (deg)
# Date Time
# 2009-01-01 00:00:00  174.460000
# 2009-01-01 01:00:00  172.416667
# 2009-01-01 02:00:00  196.816667
# 2009-01-01 03:00:00  157.083333
# 2009-01-01 04:00:00  150.093333

# %%
#Use only important features
df_0 = df.copy()
df = df[selected_features].copy()

# %%
df.values.shape
# Out:
# (70129, 9)

# %% [markdown]
# We can see from the correlation heatmap, few parameters like Relative Humidity and
# Specific Humidity are redundant. Hence we will be using select features, not all.

# %%
# train - test
split_fraction = 0.7
train_split = int(split_fraction * int(len(df)))

train_data = df.iloc[0 : train_split]
val_data = df.iloc[train_split:]
train_data.head()
# Out:
#                        p (mbar)  T (degC)  VPmax (mbar)  VPdef (mbar)  \
# Date Time
# 2009-01-01 00:00:00  996.528000 -8.304000      3.260000      0.202000
# 2009-01-01 01:00:00  996.525000 -8.065000      3.323333      0.201667
# 2009-01-01 02:00:00  996.745000 -8.763333      3.145000      0.201667
# 2009-01-01 03:00:00  996.986667 -8.896667      3.111667      0.210000
# 2009-01-01 04:00:00  997.158333 -9.348333      3.001667      0.231667
#
#                      sh (g/kg)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  \
# Date Time
# 2009-01-01 00:00:00   1.910000   1309.196000  0.520000       1.002000
# 2009-01-01 01:00:00   1.951667   1307.981667  0.316667       0.711667
# 2009-01-01 02:00:00   1.836667   1311.816667  0.248333       0.606667
# 2009-01-01 03:00:00   1.811667   1312.813333  0.176667       0.606667
# 2009-01-01 04:00:00   1.733333   1315.355000  0.290000       0.670000
#
#                        wd (deg)
# Date Time
# 2009-01-01 00:00:00  174.460000
# 2009-01-01 01:00:00  172.416667
# 2009-01-01 02:00:00  196.816667
# 2009-01-01 03:00:00  157.083333
# 2009-01-01 04:00:00  150.093333

# %% [markdown]
# ### Training and validation datasets

# %%
def prepare_dataset(df, past, future,
                    batch_size, target):
    start = past + future - 1
    x = df.iloc[:-past + 1]
    y = df.iloc[start:start + len(x)][target].values.flatten()
    # padding
    y = np.concatenate([y, np.zeros(len(x) - len(y))])
    dataset = keras.preprocessing.timeseries_dataset_from_array(
        x,
        y,
        sequence_length=past,
        batch_size=batch_size,
    )
    return dataset

# %% [markdown]
# The `timeseries_dataset_from_array` function takes in a sequence of data-points gathered at
# equal intervals, along with time series parameters such as length of the
# sequences/windows, spacing between two sequence/windows, etc., to produce batches of
# sub-timeseries inputs and targets sampled from the main timeseries.

# %%
## previous hours to consider
past = 6 
## Number of hours later to predict
future = 12

batch_size = 128


dataset_train = prepare_dataset(train_data, past, future,
                    batch_size, target = 'T (degC)')
dataset_val = prepare_dataset(val_data, past, future,
                    batch_size, target= 'T (degC)')

for batch in dataset_train.take(1):
    inputs, targets = batch
    break

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
inputs_shape = (inputs.shape[1], inputs.shape[2])
# Out:
# Input shape: (128, 6, 9)
# Target shape: (128,)

# %% [markdown]
# ### Configure the dataset for performance
#
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data.
#
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.
#
# Interested readers can learn more about both methods, as well as how to cache data to disk in the [data performance guide](https://www.tensorflow.org/guide/data_performance#prefetching).

# %%
AUTOTUNE = tf.data.AUTOTUNE
dataset_train = dataset_train.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
dataset_val = dataset_val.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Training

# %% [markdown]
# #### Normalization layer
# We can normalize the features with [Normalization layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Normalization).
#
# ```python
# tf.keras.layers.experimental.preprocessing.Normalization(
#     axis=-1, dtype=None, mean=None, variance=None, **kwargs
# )
# ```
#
# ```python
# norm = tf.keras.layers.experimental.preprocessing.Normalization()
# norm.adapt(dataset_train.map(lambda x, y: x))
#
# ```
#
#
#
# `adapt` computes mean and std of the train data and store them as the layer's weights. `adapt`
#  should be called before fit, evaluate, or predict.

# %%
norm = tf.keras.layers.experimental.preprocessing.Normalization(
    axis=-1, dtype=None, mean=None, variance=None
)
norm.adapt(dataset_train.map(lambda x, y: x))

print('Unnormalized row: ', df.iloc[:1].values)
print('Normalized row: ', norm(df.iloc[:1]))
print('Normalized df, mean row: ',norm(df.values).numpy().mean(1))
print('Normalized df, std row: ',np.std(norm(df.values).numpy(), 1))
# Out:
# Unnormalized row:  [[ 9.965280e+02 -8.304000e+00  3.260000e+00  2.020000e-01  1.910000e+00
#    1.309196e+03  5.200000e-01  1.002000e+00  1.744600e+02]]
# Normalized row:  tf.Tensor(
# [[[ 0.95019025 -2.0130825  -1.3159372  -0.7863713  -1.5056293
#     2.2524745  -1.1222371  -1.1586877   0.01899056]]], shape=(1, 1, 9), dtype=float32)
# Normalized df, mean row:  [[ 0.06562964  0.0402812   0.02969497  0.01426948  0.03669601 -0.02367499
#   -0.30721226 -0.22317867  0.02324552]]
# Normalized df, std row:  [[ 1.0111917   0.97298783  1.0079441   1.0183288   0.9948013   0.97596383
#   43.049873   30.405182    0.9836922 ]]

# %% [markdown]
# #### Create the model

# %%
norm = tf.keras.layers.experimental.preprocessing.Normalization(
    axis=-1
)
norm.adapt(dataset_train.map(lambda x, y: x))

num_features =  9
inputs_shape = (past, num_features)

inputs = keras.layers.Input(shape=inputs_shape)
inputs_norm = norm(inputs)
rnn_out = keras.layers.SimpleRNN(32)(inputs_norm)
outputs = keras.layers.Dense(1)(rnn_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), loss="mse")
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 6, 9)]            0
# _________________________________________________________________
# normalization_1 (Normalizati (None, 6, 9)              19
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 32)                1344
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,396
# Trainable params: 1,377
# Non-trainable params: 19
# _________________________________________________________________

# %% [markdown]
# We'll use the `ModelCheckpoint` callback to regularly save checkpoints, and
# the `EarlyStopping` callback to interrupt training when the validation loss
# is not longer improving.

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=3)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=25,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/25
# 384/384 [==============================] - 3s 7ms/step - loss: 105.9299 - val_loss: 39.6644
#
# Epoch 00001: val_loss improved from inf to 39.66438, saving model to model_checkpoint.h5
# Epoch 2/25
# 384/384 [==============================] - 1s 3ms/step - loss: 41.3236 - val_loss: 31.1063
#
# Epoch 00002: val_loss improved from 39.66438 to 31.10633, saving model to model_checkpoint.h5
# Epoch 3/25
# 384/384 [==============================] - 1s 2ms/step - loss: 31.4879 - val_loss: 29.2890
#
# Epoch 00003: val_loss improved from 31.10633 to 29.28896, saving model to model_checkpoint.h5
# Epoch 4/25
# 384/384 [==============================] - 1s 2ms/step - loss: 30.8482 - val_loss: 27.7945
#
# Epoch 00004: val_loss improved from 29.28896 to 27.79449, saving model to model_checkpoint.h5
# Epoch 5/25
# 384/384 [==============================] - 1s 3ms/step - loss: 31.5264 - val_loss: 27.4274
#
# Epoch 00005: val_loss improved from 27.79449 to 27.42743, saving model to model_checkpoint.h5
# Epoch 6/25
# 384/384 [==============================] - 1s 2ms/step - loss: 30.2560 - val_loss: 26.5522
#
# Epoch 00006: val_loss improved from 27.42743 to 26.55216, saving model to model_checkpoint.h5
# Epoch 7/25
# 384/384 [==============================] - 1s 2ms/step - loss: 27.6890 - val_loss: 26.9896
#
# Epoch 00007: val_loss did not improve from 26.55216
# Epoch 8/25
# 384/384 [==============================] - 1s 3ms/step - loss: 26.2687 - val_loss: 25.9890
#
# Epoch 00008: val_loss improved from 26.55216 to 25.98904, saving model to model_checkpoint.h5
# Epoch 9/25
# 384/384 [==============================] - 1s 3ms/step - loss: 28.8074 - val_loss: 25.6934
#
# Epoch 00009: val_loss improved from 25.98904 to 25.69336, saving model to model_checkpoint.h5
# Epoch 10/25
# 384/384 [==============================] - 1s 3ms/step - loss: 25.4735 - val_loss: 25.1306
#
# Epoch 00010: val_loss improved from 25.69336 to 25.13059, saving model to model_checkpoint.h5
# Epoch 11/25
# 384/384 [==============================] - 1s 2ms/step - loss: 25.1516 - val_loss: 25.4992
#
# Epoch 00011: val_loss did not improve from 25.13059
# Epoch 12/25
# 384/384 [==============================] - 1s 2ms/step - loss: 26.2345 - val_loss: 25.2401
#
# Epoch 00012: val_loss did not improve from 25.13059
# Epoch 13/25
# 384/384 [==============================] - 1s 3ms/step - loss: 26.4645 - val_loss: 24.9561
#
# Epoch 00013: val_loss improved from 25.13059 to 24.95607, saving model to model_checkpoint.h5
# Epoch 14/25
# 384/384 [==============================] - 1s 3ms/step - loss: 25.1057 - val_loss: 25.9440
#
# Epoch 00014: val_loss did not improve from 24.95607
# Epoch 15/25
# 384/384 [==============================] - 1s 3ms/step - loss: 25.3275 - val_loss: 25.9441
#
# Epoch 00015: val_loss did not improve from 24.95607
# Epoch 16/25
# 384/384 [==============================] - 1s 3ms/step - loss: 25.2425 - val_loss: 24.7462
#
# Epoch 00016: val_loss improved from 24.95607 to 24.74617, saving model to model_checkpoint.h5
# Epoch 17/25
# 384/384 [==============================] - 1s 3ms/step - loss: 25.1786 - val_loss: 24.8541
#
# Epoch 00017: val_loss did not improve from 24.74617
# Epoch 18/25
# 384/384 [==============================] - 1s 2ms/step - loss: 25.0237 - val_loss: 25.2021
#
# Epoch 00018: val_loss did not improve from 24.74617
# Epoch 19/25
# 384/384 [==============================] - 1s 2ms/step - loss: 24.8107 - val_loss: 24.4035
#
# Epoch 00019: val_loss improved from 24.74617 to 24.40355, saving model to model_checkpoint.h5
# Epoch 20/25
# 384/384 [==============================] - 1s 2ms/step - loss: 25.4174 - val_loss: 24.6552
#
# Epoch 00020: val_loss did not improve from 24.40355
# Epoch 21/25
# 384/384 [==============================] - 1s 3ms/step - loss: 25.7446 - val_loss: 24.8429
#
# Epoch 00021: val_loss did not improve from 24.40355
# Epoch 22/25
# 384/384 [==============================] - 1s 2ms/step - loss: 24.9920 - val_loss: 24.4583
#
# Epoch 00022: val_loss did not improve from 24.40355

# %% [markdown]
# We can visualize the loss with the function below. After one point, the loss stops
# decreasing.

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return

for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        future,
        "Single Step Prediction",
    )

# %%
batch_size= 500
dataset_ts = prepare_dataset(val_data, past, future,
                    batch_size, target = 'T (degC)')
for i, (x, y) in enumerate(dataset_ts):
    if i >= 3:
        break
    print('batch: ', i)
    pred = model.predict(x)
    plt.plot(y.numpy())
    plt.plot(pred)
    plt.show()
# Out:
# batch:  0
# batch:  1
# batch:  2

# %% [markdown]
# #### Question 1:  Change the `keras.layers.SimpleRNN` layer to `keras.layers.LSTM` and to `keras.layers.GRU` and compare the results
# You can also set the `recurrent_dropout` parameter
#
# ```python
# tf.keras.layers.x(
#     units,
#     dropout=0.0,
#     recurrent_dropout=0.0)
# ```

# %%
num_features = 9
inputs_shape = (past, num_features)


norm = tf.keras.layers.experimental.preprocessing.Normalization(
    axis=-1
)
norm.adapt(dataset_train.map(lambda x, y: x))

inputs = layers.Input(shape=inputs_shape)
inputs_norm = norm(inputs)

## complete the code
lstm_out = layers.GRU(128)(inputs_norm)
outputs = layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), loss="mse")

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=3)

history = model.fit(
    dataset_train,
    epochs=25,
    validation_data=dataset_val,
    callbacks=[es_callback],
)
# Out:
# Epoch 1/25
# 384/384 [==============================] - 6s 12ms/step - loss: 70.1289 - val_loss: 29.3264
# Epoch 2/25
# 384/384 [==============================] - 5s 12ms/step - loss: 32.2840 - val_loss: 30.0365
# Epoch 3/25
# 384/384 [==============================] - 5s 12ms/step - loss: 28.8973 - val_loss: 26.5728
# Epoch 4/25
# 384/384 [==============================] - 5s 12ms/step - loss: 27.5442 - val_loss: 25.8301
# Epoch 5/25
# 384/384 [==============================] - 5s 12ms/step - loss: 28.1977 - val_loss: 25.6845
# Epoch 6/25
# 384/384 [==============================] - 5s 12ms/step - loss: 27.2305 - val_loss: 26.6746
# Epoch 7/25
# 384/384 [==============================] - 5s 12ms/step - loss: 25.8743 - val_loss: 24.3122
# Epoch 8/25
# 384/384 [==============================] - 5s 12ms/step - loss: 25.9976 - val_loss: 25.6607
# Epoch 9/25
# 384/384 [==============================] - 5s 12ms/step - loss: 23.9662 - val_loss: 23.6724
# Epoch 10/25
# 384/384 [==============================] - 5s 12ms/step - loss: 25.2654 - val_loss: 23.8805
# Epoch 11/25
# 384/384 [==============================] - 5s 12ms/step - loss: 24.1535 - val_loss: 24.2060
# Epoch 12/25
# 384/384 [==============================] - 5s 12ms/step - loss: 25.3898 - val_loss: 24.1312

# %%
for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        future,
        "Single Step Prediction",
    )
    
    
batch_size= 500
dataset_ts = prepare_dataset(val_data, past, future,
                    batch_size, target = 'T (degC)')
for i, (x, y) in enumerate(dataset_ts):
    if i >= 3:
        break
    print('batch: ', i)
    pred = model.predict(x)
    plt.plot(y.numpy())
    plt.plot(pred)
    plt.show()
# Out:
# batch:  0
# batch:  1
# batch:  2

# %% [markdown]
# ### Feature Engineering
#
# Wind velocity
# One thing that should stand out is the min value of the wind velocity, wv (m/s) and max. wv (m/s) columns. This -9999 is likely erroneous. There's a separate wind direction column, so the velocity should be >=0. Replace it with zeros:

# %%
wv = df['wv (m/s)']
bad_wv = wv == -9999.0
wv[bad_wv] = 0.0
df['wv (m/s)'] = wv

max_wv = df['max. wv (m/s)']
bad_max_wv = max_wv == -9999.0
max_wv[bad_max_wv] = 0.0
df['max. wv (m/s)'] = max_wv

# %% [markdown]
# But this will be easier for the model to interpret if you convert the wind direction and velocity columns to a wind vector:

# %%
wv = df.pop('wv (m/s)')

# Convert to radians.
wd_rad = df.pop('wd (deg)')*np.pi / 180

# Calculate the wind x and y components.
df['Wx'] = wv*np.cos(wd_rad)
df['Wy'] = wv*np.sin(wd_rad)

# Calculate the max wind x and y components.
df['max Wx'] = max_wv*np.cos(wd_rad)
df['max Wy'] = max_wv*np.sin(wd_rad)

# %% [markdown]
# Similarly the Date Time column is very useful, but not in this string form. Start by converting it to seconds:
#
#
# Similar to the wind direction the time in seconds is not a useful model input. Being weather data it has clear daily and yearly periodicity. There are many ways you could deal with periodicity.
#
# A simple approach to convert it to a usable signal is to use sin and cos to convert the time to clear "Time of day" and "Time of year" signals:

# %%
from datetime import datetime
timestamp_s = df.index.map(datetime.timestamp)
day = 24*60*60
year = (365.2425)*day

df['Day sin'] = np.sin(timestamp_s * (2 * np.pi / day))
df['Day cos'] = np.cos(timestamp_s * (2 * np.pi / day))
df['Year sin'] = np.sin(timestamp_s * (2 * np.pi / year))
df['Year cos'] = np.cos(timestamp_s * (2 * np.pi / year))

# %%
df.head()
# Out:
#                        p (mbar)  T (degC)  VPmax (mbar)  VPdef (mbar)  \
# Date Time
# 2009-01-01 00:00:00  996.528000 -8.304000      3.260000      0.202000
# 2009-01-01 01:00:00  996.525000 -8.065000      3.323333      0.201667
# 2009-01-01 02:00:00  996.745000 -8.763333      3.145000      0.201667
# 2009-01-01 03:00:00  996.986667 -8.896667      3.111667      0.210000
# 2009-01-01 04:00:00  997.158333 -9.348333      3.001667      0.231667
#
#                      sh (g/kg)  rho (g/m**3)  max. wv (m/s)        Wx  \
# Date Time
# 2009-01-01 00:00:00   1.910000   1309.196000       1.002000 -0.517571
# 2009-01-01 01:00:00   1.951667   1307.981667       0.711667 -0.313897
# 2009-01-01 02:00:00   1.836667   1311.816667       0.606667 -0.237713
# 2009-01-01 03:00:00   1.811667   1312.813333       0.606667 -0.162723
# 2009-01-01 04:00:00   1.733333   1315.355000       0.670000 -0.251383
#
#                            Wy    max Wx    max Wy       Day sin   Day cos  \
# Date Time
# 2009-01-01 00:00:00  0.050201 -0.997320  0.096734 -2.588190e-01  0.965926
# 2009-01-01 01:00:00  0.041790 -0.705442  0.093917 -1.776611e-12  1.000000
# 2009-01-01 02:00:00 -0.071845 -0.580723 -0.175515  2.588190e-01  0.965926
# 2009-01-01 03:00:00  0.068793 -0.558784  0.236231  5.000000e-01  0.866025
# 2009-01-01 04:00:00  0.144591 -0.580782  0.334054  7.071068e-01  0.707107
#
#                      Year sin  Year cos
# Date Time
# 2009-01-01 00:00:00  0.008616  0.999963
# 2009-01-01 01:00:00  0.009332  0.999956
# 2009-01-01 02:00:00  0.010049  0.999950
# 2009-01-01 03:00:00  0.010766  0.999942
# 2009-01-01 04:00:00  0.011483  0.999934

# %%
# train - test
split_fraction = 0.7
train_split = int(split_fraction * int(len(df)))

train_data = df.iloc[0 : train_split]
val_data = df.iloc[train_split:]
train_data.head()
# Out:
#                        p (mbar)  T (degC)  VPmax (mbar)  VPdef (mbar)  \
# Date Time
# 2009-01-01 00:00:00  996.528000 -8.304000      3.260000      0.202000
# 2009-01-01 01:00:00  996.525000 -8.065000      3.323333      0.201667
# 2009-01-01 02:00:00  996.745000 -8.763333      3.145000      0.201667
# 2009-01-01 03:00:00  996.986667 -8.896667      3.111667      0.210000
# 2009-01-01 04:00:00  997.158333 -9.348333      3.001667      0.231667
#
#                      sh (g/kg)  rho (g/m**3)  max. wv (m/s)        Wx  \
# Date Time
# 2009-01-01 00:00:00   1.910000   1309.196000       1.002000 -0.517571
# 2009-01-01 01:00:00   1.951667   1307.981667       0.711667 -0.313897
# 2009-01-01 02:00:00   1.836667   1311.816667       0.606667 -0.237713
# 2009-01-01 03:00:00   1.811667   1312.813333       0.606667 -0.162723
# 2009-01-01 04:00:00   1.733333   1315.355000       0.670000 -0.251383
#
#                            Wy    max Wx    max Wy       Day sin   Day cos  \
# Date Time
# 2009-01-01 00:00:00  0.050201 -0.997320  0.096734 -2.588190e-01  0.965926
# 2009-01-01 01:00:00  0.041790 -0.705442  0.093917 -1.776611e-12  1.000000
# 2009-01-01 02:00:00 -0.071845 -0.580723 -0.175515  2.588190e-01  0.965926
# 2009-01-01 03:00:00  0.068793 -0.558784  0.236231  5.000000e-01  0.866025
# 2009-01-01 04:00:00  0.144591 -0.580782  0.334054  7.071068e-01  0.707107
#
#                      Year sin  Year cos
# Date Time
# 2009-01-01 00:00:00  0.008616  0.999963
# 2009-01-01 01:00:00  0.009332  0.999956
# 2009-01-01 02:00:00  0.010049  0.999950
# 2009-01-01 03:00:00  0.010766  0.999942
# 2009-01-01 04:00:00  0.011483  0.999934

# %%
sequence_length = int(past / 1)

dataset_train = prepare_dataset(train_data, past, future,
                    batch_size, target = 'T (degC)')
dataset_val = prepare_dataset(val_data, past, future,
                    batch_size, target= 'T (degC)')

for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
inputs_shape = (inputs.shape[1], inputs.shape[2])
# Out:
# Input shape: (500, 6, 15)
# Target shape: (500,)

# %%
AUTOTUNE = tf.data.AUTOTUNE
dataset_train = dataset_train.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
dataset_val = dataset_val.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Question 2:  Use the same model as before and compare the results

# %%
norm = tf.keras.layers.experimental.preprocessing.Normalization(
    axis=-1
)
norm.adapt(dataset_train.map(lambda x, y: x))

num_features = 15
inputs_shape = (past, num_features)

inputs = layers.Input(shape=inputs_shape)
inputs_norm = norm(inputs)

## complete the code
lstm_out = layers.GRU(128)(inputs_norm)
outputs = layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), loss="mse")

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=3)

history = model.fit(
    dataset_train,
    epochs=25,
    validation_data=dataset_val,
    callbacks=[es_callback],
)
# Out:
# Epoch 1/25
# 99/99 [==============================] - 7s 51ms/step - loss: 107.5873 - val_loss: 26.5867
# Epoch 2/25
# 99/99 [==============================] - 3s 33ms/step - loss: 25.9284 - val_loss: 21.4631
# Epoch 3/25
# 99/99 [==============================] - 3s 34ms/step - loss: 21.9835 - val_loss: 19.5663
# Epoch 4/25
# 99/99 [==============================] - 3s 34ms/step - loss: 22.4337 - val_loss: 18.6768
# Epoch 5/25
# 99/99 [==============================] - 3s 35ms/step - loss: 20.0096 - val_loss: 18.3676
# Epoch 6/25
# 99/99 [==============================] - 3s 35ms/step - loss: 21.9668 - val_loss: 17.4151
# Epoch 7/25
# 99/99 [==============================] - 3s 34ms/step - loss: 18.5830 - val_loss: 17.0365
# Epoch 8/25
# 99/99 [==============================] - 3s 35ms/step - loss: 19.6736 - val_loss: 16.8693
# Epoch 9/25
# 99/99 [==============================] - 4s 35ms/step - loss: 18.0240 - val_loss: 16.4569
# Epoch 10/25
# 99/99 [==============================] - 3s 34ms/step - loss: 17.6976 - val_loss: 17.2193
# Epoch 11/25
# 99/99 [==============================] - 3s 34ms/step - loss: 17.7121 - val_loss: 16.3654
# Epoch 12/25
# 99/99 [==============================] - 4s 36ms/step - loss: 18.1344 - val_loss: 16.4421
# Epoch 13/25
# 99/99 [==============================] - 3s 34ms/step - loss: 17.3034 - val_loss: 16.4035
# Epoch 14/25
# 99/99 [==============================] - 3s 35ms/step - loss: 16.7353 - val_loss: 16.2082
# Epoch 15/25
# 99/99 [==============================] - 3s 35ms/step - loss: 17.0178 - val_loss: 16.7255
# Epoch 16/25
# 99/99 [==============================] - 3s 34ms/step - loss: 17.5511 - val_loss: 16.1162
# Epoch 17/25
# 99/99 [==============================] - 3s 34ms/step - loss: 18.2596 - val_loss: 16.8472
# Epoch 18/25
# 99/99 [==============================] - 3s 35ms/step - loss: 17.3376 - val_loss: 15.7551
# Epoch 19/25
# 99/99 [==============================] - 3s 34ms/step - loss: 15.9097 - val_loss: 16.5495
# Epoch 20/25
# 99/99 [==============================] - 3s 34ms/step - loss: 17.2068 - val_loss: 15.9151
# Epoch 21/25
# 99/99 [==============================] - 3s 35ms/step - loss: 16.0965 - val_loss: 15.7426
# Epoch 22/25
# 99/99 [==============================] - 3s 35ms/step - loss: 16.4834 - val_loss: 15.7787
# Epoch 23/25
# 99/99 [==============================] - 3s 35ms/step - loss: 16.9190 - val_loss: 15.7770
# Epoch 24/25
# 99/99 [==============================] - 3s 35ms/step - loss: 17.1121 - val_loss: 15.6893
# Epoch 25/25
# 99/99 [==============================] - 3s 35ms/step - loss: 16.6583 - val_loss: 15.7430

# %%
for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        future,
        "Single Step Prediction",
    )
    
    
batch_size= 500
dataset_ts = prepare_dataset(val_data, past, future,
                    batch_size, target = 'T (degC)')
for i, (x, y) in enumerate(dataset_ts):
    if i >= 3:
        break
    print('batch: ', i)
    pred = model.predict(x)
    plt.plot(y.numpy())
    plt.plot(pred)
    plt.show()
# Out:
# batch:  0
# batch:  1
# batch:  2

# %% [markdown]
# ### Question 3:  Create a deep model stacking two recurrent layers

# %%
num_features = 15
inputs_shape = (past, num_features)


norm = tf.keras.layers.experimental.preprocessing.Normalization(
    axis=-1
)
norm.adapt(dataset_train.map(lambda x, y: x))

inputs = layers.Input(shape=inputs_shape)
inputs_norm = norm(inputs)

## complete the code
l_1 = keras.layers.LSTM(128, return_sequences=True)(inputs_norm)
l_2 = keras.layers.LSTM(128, return_sequences=False)(l_1)

outputs = keras.layers.Dense(1)(l_2)


model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), loss="mse")

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=3)

history = model.fit(
    dataset_train,
    epochs=25,
    validation_data=dataset_val,
    callbacks=[es_callback],
)
# Out:
# Epoch 1/25
# 99/99 [==============================] - 13s 100ms/step - loss: 99.1160 - val_loss: 25.7446
# Epoch 2/25
# 99/99 [==============================] - 9s 93ms/step - loss: 25.5994 - val_loss: 20.7848
# Epoch 3/25
# 99/99 [==============================] - 10s 96ms/step - loss: 21.0902 - val_loss: 19.0738
# Epoch 4/25
# 99/99 [==============================] - 9s 93ms/step - loss: 20.8022 - val_loss: 18.4013
# Epoch 5/25
# 99/99 [==============================] - 9s 92ms/step - loss: 19.7898 - val_loss: 16.8721
# Epoch 6/25
# 99/99 [==============================] - 9s 95ms/step - loss: 18.0521 - val_loss: 17.8089
# Epoch 7/25
# 99/99 [==============================] - 9s 92ms/step - loss: 18.6275 - val_loss: 18.0505
# Epoch 8/25
# 99/99 [==============================] - 9s 92ms/step - loss: 19.4283 - val_loss: 17.4548

# %%
for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        future,
        "Single Step Prediction",
    )
    
    
batch_size= 500
dataset_ts = prepare_dataset(val_data, past, future,
                    batch_size, target = 'T (degC)')
for i, (x, y) in enumerate(dataset_ts):
    if i >= 3:
        break
    print('batch: ', i)
    pred = model.predict(x)
    plt.plot(y.numpy())
    plt.plot(pred)
    plt.show()
# Out:
# batch:  0
# batch:  1
# batch:  2

# %% [markdown]
# ### Question 4:  Use `Bidirectional`  layer
#
# ```python
# layers.Bidirectional(layers.LSTM(64, return_sequences=)
# ````

# %%
inputs_shape = (past, num_features)

norm = tf.keras.layers.experimental.preprocessing.Normalization(
    axis=-1
)
norm.adapt(dataset_train.map(lambda x, y: x))


inputs = layers.Input(shape=inputs_shape)
inputs_norm = norm(inputs)

## complete the code
l_1 = layers.Bidirectional(layers.LSTM(128, return_sequences=False))(inputs_norm)

outputs = keras.layers.Dense(1)(l_1)


model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), loss="mse")

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=3)

history = model.fit(
    dataset_train,
    epochs=25,
    validation_data=dataset_val,
    callbacks=[es_callback],
)
# Out:
# Epoch 1/25
# 99/99 [==============================] - 10s 76ms/step - loss: 115.7925 - val_loss: 22.3867
# Epoch 2/25
# 99/99 [==============================] - 7s 76ms/step - loss: 24.8273 - val_loss: 18.8084
# Epoch 3/25
# 99/99 [==============================] - 7s 72ms/step - loss: 20.9892 - val_loss: 18.2242
# Epoch 4/25
# 99/99 [==============================] - 8s 79ms/step - loss: 19.3337 - val_loss: 18.1369
# Epoch 5/25
# 99/99 [==============================] - 10s 99ms/step - loss: 18.8087 - val_loss: 17.6168
# Epoch 6/25
# 99/99 [==============================] - 10s 103ms/step - loss: 18.3395 - val_loss: 16.7953
# Epoch 7/25
# 99/99 [==============================] - 10s 97ms/step - loss: 17.9185 - val_loss: 16.9640
# Epoch 8/25
# 99/99 [==============================] - 9s 94ms/step - loss: 16.6382 - val_loss: 17.6013
# Epoch 9/25
# 99/99 [==============================] - 8s 83ms/step - loss: 17.1985 - val_loss: 16.1415
# Epoch 10/25
# 99/99 [==============================] - 7s 71ms/step - loss: 17.2097 - val_loss: 16.6871
# Epoch 11/25
# 99/99 [==============================] - 7s 67ms/step - loss: 18.1213 - val_loss: 16.2968
# Epoch 12/25
# 99/99 [==============================] - 7s 69ms/step - loss: 16.5275 - val_loss: 16.7431

# %%
for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        future,
        "Single Step Prediction",
    )
    
    
batch_size= 500
dataset_ts = prepare_dataset(val_data, past, future,
                    batch_size, target = 'T (degC)')
for i, (x, y) in enumerate(dataset_ts):
    if i >= 3:
        break
    print('batch: ', i)
    pred = model.predict(x)
    plt.plot(y.numpy())
    plt.plot(pred)
    plt.show()
# Out:
# batch:  0
# batch:  1
# batch:  2

# %% [markdown]
# ### Question 5:  Obtain a good model for predicting the temperature in 24h
#
# Try different architectures and different values for `past`

# %%
future = 24

# %%
past = 18
batch_size = 128
dataset_train = prepare_dataset(train_data, past, future,
                    batch_size, target = 'T (degC)')
dataset_val = prepare_dataset(val_data, past, future,
                    batch_size, target= 'T (degC)')

for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
inputs_shape = (inputs.shape[1], inputs.shape[2])
# Out:
# Input shape: (128, 18, 15)
# Target shape: (128,)

# %%
AUTOTUNE = tf.data.AUTOTUNE
dataset_train = dataset_train.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
dataset_val = dataset_val.cache().prefetch(buffer_size=AUTOTUNE)

# %%
norm = tf.keras.layers.experimental.preprocessing.Normalization(
    axis=-1
)
norm.adapt(dataset_train.map(lambda x, y: x))


inputs = layers.Input(shape=(past, 15))
inputs_norm = norm(inputs)


l_1 = keras.layers.GRU(128, return_sequences=True)(inputs_norm)
l_1 = keras.layers.GRU(128, return_sequences=False)(l_1)


outputs = keras.layers.Dense(1)(l_1)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), loss="mse")

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=3)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=25,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/25
# 384/384 [==============================] - 36s 86ms/step - loss: 60.7133 - val_loss: 31.5615
#
# Epoch 00001: val_loss improved from inf to 31.56154, saving model to model_checkpoint.h5
# Epoch 2/25
# 384/384 [==============================] - 37s 97ms/step - loss: 29.9410 - val_loss: 27.2011
#
# Epoch 00002: val_loss improved from 31.56154 to 27.20114, saving model to model_checkpoint.h5
# Epoch 3/25
# 384/384 [==============================] - 33s 86ms/step - loss: 30.0987 - val_loss: 26.5080
#
# Epoch 00003: val_loss improved from 27.20114 to 26.50803, saving model to model_checkpoint.h5
# Epoch 4/25
# 384/384 [==============================] - 35s 92ms/step - loss: 29.0003 - val_loss: 26.5841
#
# Epoch 00004: val_loss did not improve from 26.50803
# Epoch 5/25
# 384/384 [==============================] - 40s 103ms/step - loss: 27.6745 - val_loss: 26.6638
#
# Epoch 00005: val_loss did not improve from 26.50803
# Epoch 6/25
# 384/384 [==============================] - 39s 102ms/step - loss: 28.0515 - val_loss: 26.5734
#
# Epoch 00006: val_loss did not improve from 26.50803

# %%
for x, y in dataset_val.take(5):
    show_plot(
        [x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],
        future,
        "Single Step Prediction",
    )
    
    
batch_size= 500
dataset_ts = prepare_dataset(val_data, past, future,
                    batch_size, target = 'T (degC)')
for i, (x, y) in enumerate(dataset_ts):
    if i >= 3:
        break
    print('batch: ', i)
    pred = model.predict(x)
    plt.plot(y.numpy())
    plt.plot(pred)
    plt.show()
# Out:
# batch:  0
# batch:  1
# batch:  2

# %% [markdown]
# ## Practice: Cryptocurrency Forecasting

# %% [markdown]
# First of all, obtain and pre-process the data from [www.cryptodatadownload.com](www.cryptodatadownload.com)

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# http://www.cryptodatadownload.com/cdd/gemini_{0}USD_1hr.csv
# '../data/gemini_{0}USD_1hr.csv'
def get_coin_df(fpath='../data/gemini_{0}USD_1hr.csv'):
    coins = ['BTC', 'ETH', 'LTC', 'ZEC']
    coins = ['BTC', 'ETH']
    file_path = fpath.format('BTC')
    print(file_path)
    df = pd.read_csv(file_path, parse_dates=['Date'], skiprows=1, skipfooter=1)
    df = df[['Date', 'Open']]
    df = df.set_index('Date')
    df = df.sort_index()
    df = df.rename(columns={'Open': 'BTC'})
    for coin in ['ETH', 'LTC', 'ZEC']:
        coin_path = fpath.format(coin)
        df_coin = pd.read_csv(coin_path,
                              parse_dates=['Date'],
                              skiprows=1,
                              skipfooter=1)
        df_coin = df_coin[['Date', 'Open']]
        df_coin = df_coin.set_index('Date')
        df_coin = df_coin.sort_index()
        df_coin = df_coin.rename(columns={'Open': coin})
        df[coin] = np.nan
        df.loc[df_coin.index, coin] = df_coin.values.flatten()
    return df


df = get_coin_df(
    fpath='http://www.cryptodatadownload.com/cdd/gemini_{0}USD_1hr.csv')
df.tail()
# Out:
# http://www.cryptodatadownload.com/cdd/gemini_BTCUSD_1hr.csv
# <ipython-input-82-8cf04f14db60>:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(file_path, parse_dates=['Date'], skiprows=1, skipfooter=1)
# <ipython-input-82-8cf04f14db60>:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df_coin = pd.read_csv(coin_path,
#                           BTC      ETH     LTC     ZEC
# Date
# 2021-03-31 20:00:00  58650.40  1901.12  192.90  154.26
# 2021-03-31 21:00:00  59000.61  1940.64  195.68  156.15
# 2021-03-31 22:00:00  58934.87  1930.51  195.59  155.04
# 2021-03-31 23:00:00  58655.46  1906.17  194.87  155.12
# 2021-04-01 00:00:00  58803.84  1918.91  196.71  158.25

# %%
# df = df.diff()
# df[df.columns] = np.sqrt(df.values)

# %% [markdown]
# Lets visualize the scaled values

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()

# Create an object to transform the data to fit minmax processor
x_scaled = scaler.fit_transform(df)

# Run the normalizer on the dataframe
df_normalized = pd.DataFrame(x_scaled, columns=df.columns, index=df.index)

# %%
coins = ['BTC', 'ETH', 'LTC', 'ZEC']
for col in coins:
    df_normalized[col].plot(legend=True, figsize=(15, 7))
plt.ylabel('Dolars scaled')
plt.grid()
plt.show()

# %% [markdown]
# ### Univariate Time Series
# To start with, we will use only one cryptocurrency.

# %%
coin_target = 'ETH' #  Coin that we want to predict, ['BTC', 'ETH', 'LTC', 'ZEC']
df_coin = df[coin_target].copy()
# delete nan rows
df_coin = df_coin.dropna()
df_coin.head()
# Out:
# Date
# 2016-05-09 14:00:00     9.55
# 2016-05-09 15:00:00    10.00
# 2016-05-09 16:00:00     9.99
# 2016-05-09 17:00:00     9.83
# 2016-05-09 18:00:00     9.49
# Name: ETH, dtype: float64

# %%
df_coin.plot(legend=True,figsize=(10,5))
plt.ylabel(coin_target)
plt.show()

# %%
# Train-test split
test_date = pd.Timestamp("2020-02-15")
init_date = pd.Timestamp("2017-10-08 14:00:00")

# train_data = df_coin.loc[df_coin.index < test_date].values

train_data = df_coin.loc[(df_coin.index < test_date) *
                         (df_coin.index > init_date)].values

test_data = df_coin.loc[df_coin.index >= test_date].values

# %% [markdown]
# #### Data normalization

# %%
mu = train_data.mean()
sigma = train_data.std()
print('mu, sigma: ', mu, sigma)

train_data = (train_data - mu) / sigma
test_data = (test_data - mu) / sigma
# Out:
# mu, sigma:  333.52481405149774 250.91562011651556

# %% [markdown]
# #### Transform input array to time series matrix
#
# For example if  `dataset = [0,1,2,3,4,5,6]` :
#
# If we have `past=3`, and `future=2`, we use **windows of size 3** for predicting **2 steps ahead**.
#
# we are going to use `[0,1,2] (length=past=3)` to predict `4`,
#
# We need too create a training data like
# ```python
# [0,1,2], 4
# [1,2,3], 5
# [2,3,4], 6
# ```

# %%
import random

def convert2matrix(data_arr, past, future, shuffle=False):
    X, Y = [], []
    size = len(data_arr)
    for i in range(size - future - past + 1):
        d = i + past
        y_ind = i + past + future - 1
        X.append(data_arr[i:d])
        Y.append(data_arr[y_ind])
    if shuffle:
        c = list(zip(X, Y))
        random.shuffle(c)
        X, Y = zip(*c)
    return np.array(X), np.array(Y)

# %% [markdown]
# Check that the function works, we should obtain:
# ```python
# [0,1,2], 4
# [1,2,3], 5
# [2,3,4], 6
# ````

# %%
X_trial, y_trial = convert2matrix(np.array([0, 1, 2, 3, 4, 5, 6]),
                                  past=3,
                                  future=2,
                                  shuffle=False)
for ind in range(len(y_trial)):
    print(X_trial[ind, :], y_trial[ind])
# Out:
# [0 1 2] 4
# [1 2 3] 5
# [2 3 4] 6

# %% [markdown]
# ### Question 1: Create a model to predict the ETH value in 24h, `RMSE(test) < 50$`

# %%
# Create windows
past, future = (24, 24)
X_train, y_train = convert2matrix(train_data, past, future, shuffle=True)
X_test, y_test = convert2matrix(test_data, past, future)

# %%
X_test[0, :], y_test[0], test_data[:past + future]
# Out:
# (array([-0.18749257, -0.18908673, -0.21519112, -0.21423463, -0.20287623,
#         -0.20598484, -0.21802076, -0.20941229, -0.21339769, -0.20215885,
#         -0.19649958, -0.20032557, -0.20494864, -0.20311535, -0.20407185,
#         -0.20494864, -0.23703113, -0.2628964 , -0.27903729, -0.26253772,
#         -0.26743976, -0.26500867, -0.26086385, -0.26337465]),
#  -0.31032270535943646,
#  array([-0.18749257, -0.18908673, -0.21519112, -0.21423463, -0.20287623,
#         -0.20598484, -0.21802076, -0.20941229, -0.21339769, -0.20215885,
#         -0.19649958, -0.20032557, -0.20494864, -0.20311535, -0.20407185,
#         -0.20494864, -0.23703113, -0.2628964 , -0.27903729, -0.26253772,
#         -0.26743976, -0.26500867, -0.26086385, -0.26337465, -0.27333816,
#         -0.27070779, -0.26170078, -0.23910354, -0.2485091 , -0.24169406,
#         -0.24938589, -0.24651639, -0.25078078, -0.24791129, -0.25460676,
#         -0.26696151, -0.26795787, -0.26823684, -0.26321524, -0.28146838,
#         -0.29462022, -0.34710798, -0.32989104, -0.31626096, -0.33028958,
#         -0.32144198, -0.32582593, -0.31032271]))

# %%
from tensorflow.keras import layers
## Modify the initial model to obtain better results

inputs = keras.layers.Input(shape=(past, 1))

'''l_1 = layers.LSTM(128, return_sequences=False) (inputs) 
l_1 = layers.Dropout(0.4)(l_1)
#l_1 = layers.Dense(16, activation='relu')(l_1)
'''
####


l_1 = layers.Conv1D(32, 3, activation='relu', padding='same')(inputs)
l_1 = layers.Conv1D(32, 3, activation='relu')(l_1)
l_1 = layers.Conv1D(32, 3, activation='relu')(l_1)
l_1 = layers.Flatten()(l_1)
l_1 = layers.Dense(16, activation='relu')(l_1)



outputs = layers.Dense(1)(l_1)
model = keras.Model(inputs=inputs, outputs=outputs)




model.compile(optimizer=keras.optimizers.Adam(), loss="mse")
model.summary()

es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=8)

history = model.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2, shuffle=True, batch_size = 128, callbacks=[es_callback]
)
# Out:
# Model: "model_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_48 (InputLayer)        [(None, 24, 1)]           0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 24, 32)            128
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 22, 32)            3104
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 20, 32)            3104
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 640)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 16)                10256
# _________________________________________________________________
# dense_66 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 16,609
# Trainable params: 16,609
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 129/129 [==============================] - 1s 7ms/step - loss: 0.2117 - val_loss: 0.0171
# Epoch 2/10
# 129/129 [==============================] - 1s 6ms/step - loss: 0.0168 - val_loss: 0.0157
# Epoch 3/10
# 129/129 [==============================] - 1s 6ms/step - loss: 0.0158 - val_loss: 0.0154
# Epoch 4/10
# 129/129 [==============================] - 1s 6ms/step - loss: 0.0176 - val_loss: 0.0173
# Epoch 5/10
# 129/129 [==============================] - 1s 5ms/step - loss: 0.0174 - val_loss: 0.0148
# Epoch 6/10
# 129/129 [==============================] - 1s 5ms/step - loss: 0.0148 - val_loss: 0.0149
# Epoch 7/10
# 129/129 [==============================] - 1s 6ms/step - loss: 0.0146 - val_loss: 0.0144
# Epoch 8/10
# 129/129 [==============================] - 1s 6ms/step - loss: 0.0144 - val_loss: 0.0181
# Epoch 9/10
# 129/129 [==============================] - 1s 6ms/step - loss: 0.0130 - val_loss: 0.0216
# Epoch 10/10
# 129/129 [==============================] - 1s 6ms/step - loss: 0.0148 - val_loss: 0.0188

# %%
results = model.evaluate(X_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))
# Out:
# 307/307 [==============================] - 0s 1ms/step - loss: 0.0960A: 0s - loss: 0.02
# Test Loss: 0.0960177332162857

# %%
y_pred = model.predict(X_test).flatten() * sigma + mu
y_target = y_test * sigma + mu
diff = y_pred - y_target
print('max deviation: ', np.abs(y_pred - y_target).max())
print('RMSE: ', np.mean((y_pred - y_target)**2)**0.5)
print('MAE: ', np.abs(y_pred - y_target).mean())

plt.figure(figsize=(12, 8))
plt.plot(y_target)
plt.plot(y_pred)
plt.legend(['True {0}'.format(coin_target), 'Predictions {0}'.format(coin_target)])
plt.show()
# Out:
# max deviation:  368.42596435546875
# RMSE:  77.75055131446602
# MAE:  41.61249665400772

# %% [markdown]
# ## Multivariate Time Series

# %%
## You can try feature engineering with df
coin_target = 'ETH' # 'BTC'
coins =  ['ETH', 'LTC', 'ZEC', 'BTC'] # ['BTC', 'ETH', 'LTC', 'ZEC']
df_multi = df[coins].dropna()

# %%
def convert2matrix_multi(df, past, future, target, shuffle=False):
    X, Y = [], []
    size = len(df)
    for i in range(size - future - past + 1):
        d = i + past
        y_ind = i + past + future - 1
        X.append(df.iloc[i:d, :].values)
        Y.append(df.iloc[y_ind][target])
    if shuffle:
        c = list(zip(X, Y))
        random.shuffle(c)
        X, Y = zip(*c)
    return np.array(X), np.array(Y)


#train_data = df_multi.loc[df_multi.index < test_date, :]
train_data = df_multi.loc[(df_multi.index < test_date) * (df_multi.index > init_date ), : ].copy()
test_data = df_multi.loc[df_multi.index >= test_date, :].copy()

# %% [markdown]
# #### Normalize Data

# %%
mu_dict = {}
sigma_dict = {}
for c in coins:
    mu = train_data[c].mean()
    sigma = train_data[c].std()
    mu_dict[c] = mu
    sigma_dict[c] = sigma
    print('coin: {0} , mu,sigma'.format(c), mu, sigma)
print(mu_dict, sigma_dict)

# %%
for c in coins:
    mu = mu_dict[c]
    sigma = sigma_dict[c]
    train_data.loc[:, c] = (train_data[c].values - mu) / sigma
    test_data.loc[:, c] = (test_data[c].values - mu) / sigma
train_data.describe()

# %% [markdown]
# ### Question 2: Create a model to predict the ETH value in 24h, `RMSE(test) < 50$`

# %%
## Create windows
past, future = (..., 24)
X_train, y_train = convert2matrix_multi(
    train_data, past, future, target=coin_target, shuffle=True)
X_test, y_test = convert2matrix_multi(
    test_data, past, future, target=coin_target, shuffle=False)

# %%
X_train.shape, y_train.shape, X_test.shape

# %%
from tensorflow.keras import layers

inputs = keras.layers.Input(shape=(past, len(coins)))
...
outputs = layers.Dense(1)(...)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(), loss="mse")

model.summary()
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", min_delta=0, patience=8)

history = model.fit(
    X_train, y_train,
    epochs=50,
    validation_split=0.2, shuffle=True, batch_size = 64, callbacks=[es_callback]
)

# %%
results = model.evaluate(X_test, y_test, verbose=1)
print('Test Loss: {}'.format(results))

# %%
sigma = sigma_dict[coin_target]
mu = mu_dict[coin_target]
y_pred = model.predict(X_test).flatten() * sigma + mu
y_target = y_test * sigma + mu
diff = y_pred - y_target
print('max deviation: ', np.abs(y_pred - y_target).max())
print('RMSE: ', np.mean((y_pred - y_target)**2)**0.5)
print('MAE: ', np.abs(y_pred - y_target).mean())

plt.figure(figsize=(12, 8))
plt.plot(y_target)
plt.plot(y_pred)
plt.legend(['True {0}'.format(coin_target), 'Predictions {0}'.format(coin_target)])
plt.show()

# %% [markdown]
# ## References
#
# https://www.tensorflow.org/guide/keras/rnn
#
# https://keras.io/examples/timeseries/timeseries_weather_forecasting/
